# %% [markdown]
# # Univariate timeseries

# %%
# Disable warnings
import warnings
warnings.simplefilter(action="ignore")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from sktime.transformations.series.fourier import FourierFeatures
from sktime.forecasting.compose import ForecastingPipeline
from numpyro import distributions as dist

from hierarchical_prophet.sktime.prophet import Prophet

# %% [markdown]
# # Import dataset
#
# We import a dataset from Prophet's original repository. We then put it into sktime-friendly format, where the index is a `pd.PeriodIndex` and the colums are the time series.

# %%
df = pd.read_csv(
    "https://raw.githubusercontent.com/facebook/prophet/main/examples/example_wp_log_peyton_manning.csv"
)
df["ds"] = pd.to_datetime(df["ds"]).dt.to_period("D")
y = df.set_index("ds")
display(y)
# Out:
#                     y
# ds
# 2007-12-10   9.590761
# 2007-12-11   8.519590
# 2007-12-12   8.183677
# 2007-12-13   8.072467
# 2007-12-14   7.893572
# ...               ...
# 2016-01-16   7.817223
# 2016-01-17   9.273878
# 2016-01-18  10.333775
# 2016-01-19   9.125871
# 2016-01-20   8.891374
#
# [2905 rows x 1 columns]

# %% [markdown]
# # Fit model
#
# Here, we fit the univariate Prophet. Note that we are not using any external regressors but, because of `yearly_seasonality=True`and `weekly_seasonality=True`, they are built internally with sktime's FourierFeatures. As `exogenous_priors` is not passed as hyperparameter, the default values are used for all regressor variables (including the Fourier features).

# %%
import numpyro
from hierarchical_prophet.effects import LinearEffect
model = Prophet(
    trend="linear",
    changepoint_interval=300,
    changepoint_prior_scale=0.0001,
    seasonality_mode="multiplicative",
    yearly_seasonality=True,
    weekly_seasonality=True,
    default_exogenous_prior=("Normal", 0, 0.01),
    #exogenous_effects={"sin": ("^sin_.*", LinearEffect("sin", effect_mode="multiplicative"))},
    noise_scale=0.05,
    mcmc_chains=1,
    mcmc_samples=300,
    mcmc_warmup=3000,
    optimizer_name="Adam",
    optimizer_kwargs={"step_size": 0.0001},
    inference_method="mcmc",
)
_ = model.fit(y=y)
# Out:
# sample: 100%|██████████| 3300/3300 [01:57<00:00, 28.17it/s, 1023 steps of size 1.67e-04. acc. prob=0.94]

# %% [markdown]
# ## Verify the trace of MCMC
#
#
# Verifying the trace of MCMC is a good way to check if the model has converged. If the trace is not stable, it is a sign that the model has not converged.

# %%
#model.plot_trace()
#plt.show()

# %% [markdown]
# ## Forecasting

# %%
forecast_horizon = pd.period_range("2007-01-01", "2018-01-01", freq="D")
fig, ax = plt.subplots(figsize=(10, 5))
preds = model.predict(fh=forecast_horizon)
preds.plot.line(ax=ax)
ax.scatter(y.index, y, marker="o", color="k", s=2, alpha=0.5)

# %%
model.predictive_samples_["obs"].shape
# Out:
# (300, 4019, 1)

# %%
quantiles = model.predict_quantiles(fh=forecast_horizon, alpha=[0.1, 0.9])
fig, ax = plt.subplots(figsize=(10, 5))
# Plot area between quantiles
ax.fill_between(quantiles.index.to_timestamp(), quantiles.iloc[:, 0], quantiles.iloc[:, -1], alpha=0.5)
ax.scatter(y.index, y, marker="o", color="k", s=2, alpha=1)

# %% [markdown]
# ## Use the hierarchical model to forecast the univariate series
#
# This model is also compatible with univariate timeseries. In this case, however, we need to introduce a dummy hierarchy to the index to the series `y`.

# %%
y_hier = y.copy()
# Add constant index level at index level 0, so that y_hier is multiindex
y_hier.index = pd.MultiIndex.from_tuples(
    [("series", i) for i in y_hier.index], names=["hier", "time"]
)
y_hier
# Out:
#                            y
# hier   time
# series 2007-12-10   9.590761
#        2007-12-11   8.519590
#        2007-12-12   8.183677
#        2007-12-13   8.072467
#        2007-12-14   7.893572
# ...                      ...
#        2016-01-16   7.817223
#        2016-01-17   9.273878
#        2016-01-18  10.333775
#        2016-01-19   9.125871
#        2016-01-20   8.891374
#
# [2905 rows x 1 columns]

# %%
from hierarchical_prophet.sktime.multivariate import HierarchicalProphet
model_hier = HierarchicalProphet(
                mcmc_chains=1,
                mcmc_samples=500,
                mcmc_warmup=1000,
                trend="linear",
                seasonality_mode="additive",
                changepoint_prior_scale=0.01,
                transformer_pipeline=FourierFeatures(
                    fourier_terms_list=[10, 2], sp_list=["Y", "W"]
                ),
                changepoint_interval=300,
                changepoint_range=-8,
                noise_scale=1,
                default_exogenous_prior=(dist.Normal, 0, 0.2),
            )


model_hier.fit(y=y_hier)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 19
#       1 from hierarchical_prophet.sktime.multivariate import HierarchicalProphet
#       2 model_hier = HierarchicalProphet(
#       3                 mcmc_chains=1,
#       4                 mcmc_samples=500,
#    (...)
#      15                 default_exogenous_prior=(dist.Normal, 0, 0.2),
#      16             )
# ---> 19 model_hier.fit(y=y_hier)
#
# File ~/Documents/personal_workspace/hierarchical_prophet/.venv/lib/python3.11/site-packages/sktime/forecasting/base/_base.py:380, in BaseForecaster.fit(self, y, X, fh)
#     378 # we call the ordinary _fit if no looping/vectorization needed
#     379 if not vectorization_needed:
# --> 380     self._fit(y=y_inner, X=X_inner, fh=fh)
#     381 else:
#     382     # otherwise we call the vectorized version of fit
#     383     self._vectorize("fit", y=y_inner, X=X_inner, fh=fh)
#
# File ~/Documents/personal_workspace/hierarchical_prophet/src/hierarchical_prophet/sktime/base.py:158, in BaseBayesianForecaster._fit(self, y, X, fh)
#     155 else:
#     156     raise ValueError(f"Unknown method {self.inference_method}")
# --> 158 self.inference_engine_.infer(**data)
#     159 self.posterior_samples_ = self.inference_engine_.posterior_samples_
#     161 return self
#
# File ~/Documents/personal_workspace/hierarchical_prophet/src/hierarchical_prophet/engine.py:40, in MAPInferenceEngine.infer(self, **kwargs)
#      38 self.guide_ = AutoDelta(self.model, init_loc_fn=init_to_mean())
#      39 self.svi_ = SVI(self.model, self.guide_, self.optimizer, loss=Trace_ELBO())
# ---> 40 self.run_results_ = self.svi_.run(
#      41     rng_key=self.rng_key, num_steps=self.num_steps, **kwargs
#      42 )
#      43 self.posterior_samples_ = self.guide_.sample_posterior(self.rng_key, params=self.run_results_.params, **kwargs)
#      44 return self
#
# File ~/Documents/personal_workspace/hierarchical_prophet/.venv/lib/python3.11/site-packages/numpyro/infer/svi.py:357, in SVI.run(self, rng_key, num_steps, progress_bar, stable_update, init_state, init_params, *args, **kwargs)
#     354     return svi_state, loss
#     356 if init_state is None:
# --> 357     svi_state = self.init(rng_key, *args, init_params=init_params, **kwargs)
#     358 else:
#     359     svi_state = init_state
#
# File ~/Documents/personal_workspace/hierarchical_prophet/.venv/lib/python3.11/site-packages/numpyro/infer/svi.py:184, in SVI.init(self, rng_key, init_params, *args, **kwargs)
#     182 if init_params is not None:
#     183     guide_init = substitute(guide_init, init_params)
# --> 184 guide_trace = trace(guide_init).get_trace(*args, **kwargs, **self.static_kwargs)
#     185 init_guide_params = {
#     186     name: site["value"]
#     187     for name, site in guide_trace.items()
#     188     if site["type"] == "param"
#     189 }
#     190 if init_params is not None:
#
# File ~/Documents/personal_workspace/hierarchical_prophet/.venv/lib/python3.11/site-packages/numpyro/handlers.py:171, in trace.get_trace(self, *args, **kwargs)
#     163 def get_trace(self, *args, **kwargs):
#     164     """
#     165     Run the wrapped callable and return the recorded trace.
#     166
#    (...)
#     169     :return: `OrderedDict` containing the execution trace.
#     170     """
# --> 171     self(*args, **kwargs)
#     172     return self.trace
#
# File ~/Documents/personal_workspace/hierarchical_prophet/.venv/lib/python3.11/site-packages/numpyro/primitives.py:105, in Messenger.__call__(self, *args, **kwargs)
#     103     return self
#     104 with self:
# --> 105     return self.fn(*args, **kwargs)
#
# File ~/Documents/personal_workspace/hierarchical_prophet/.venv/lib/python3.11/site-packages/numpyro/primitives.py:105, in Messenger.__call__(self, *args, **kwargs)
#     103     return self
#     104 with self:
# --> 105     return self.fn(*args, **kwargs)
#
# File ~/Documents/personal_workspace/hierarchical_prophet/.venv/lib/python3.11/site-packages/numpyro/infer/autoguide.py:430, in AutoDelta.__call__(self, *args, **kwargs)
#     427 def __call__(self, *args, **kwargs):
#     428     if self.prototype_trace is None:
#     429         # run model to inspect the model structure
# --> 430         self._setup_prototype(*args, **kwargs)
#     432     plates = self._create_plates(*args, **kwargs)
#     433     result = {}
#
# File ~/Documents/personal_workspace/hierarchical_prophet/.venv/lib/python3.11/site-packages/numpyro/infer/autoguide.py:404, in AutoDelta._setup_prototype(self, *args, **kwargs)
#     403 def _setup_prototype(self, *args, **kwargs):
# --> 404     super()._setup_prototype(*args, **kwargs)
#     405     with numpyro.handlers.block():
#     406         self._init_locs = {
#     407             k: v
#     408             for k, v in self._postprocess_fn(self._init_locs).items()
#     409             if k in self._init_locs
#     410         }
#
# File ~/Documents/personal_workspace/hierarchical_prophet/.venv/lib/python3.11/site-packages/numpyro/infer/autoguide.py:154, in AutoGuide._setup_prototype(self, *args, **kwargs)
#     147 rng_key = numpyro.prng_key()
#     148 with handlers.block():
#     149     (
#     150         init_params,
#     151         self._potential_fn_gen,
#     152         postprocess_fn_gen,
#     153         self.prototype_trace,
# --> 154     ) = initialize_model(
#     155         rng_key,
#     156         self.model,
#     157         init_strategy=self.init_loc_fn,
#     158         dynamic_args=True,
#     159         model_args=args,
#     160         model_kwargs=kwargs,
#     161     )
#     162 self._potential_fn = self._potential_fn_gen(*args, **kwargs)
#     163 postprocess_fn = postprocess_fn_gen(*args, **kwargs)
#
# File ~/Documents/personal_workspace/hierarchical_prophet/.venv/lib/python3.11/site-packages/numpyro/infer/util.py:656, in initialize_model(rng_key, model, init_strategy, dynamic_args, model_args, model_kwargs, forward_mode_differentiation, validate_grad)
#     646 model_kwargs = {} if model_kwargs is None else model_kwargs
#     647 substituted_model = substitute(
#     648     seed(model, rng_key if is_prng_key(rng_key) else rng_key[0]),
#     649     substitute_fn=init_strategy,
#     650 )
#     651 (
#     652     inv_transforms,
#     653     replay_model,
#     654     has_enumerate_support,
#     655     model_trace,
# --> 656 ) = _get_model_transforms(substituted_model, model_args, model_kwargs)
#     657 # substitute param sites from model_trace to model so
#     658 # we don't need to generate again parameters of `numpyro.module`
#     659 model = substitute(
#     660     model,
#     661     data={
#    (...)
#     665     },
#     666 )
#
# File ~/Documents/personal_workspace/hierarchical_prophet/.venv/lib/python3.11/site-packages/numpyro/infer/util.py:450, in _get_model_transforms(model, model_args, model_kwargs)
#     448 def _get_model_transforms(model, model_args=(), model_kwargs=None):
#     449     model_kwargs = {} if model_kwargs is None else model_kwargs
# --> 450     model_trace = trace(model).get_trace(*model_args, **model_kwargs)
#     451     inv_transforms = {}
#     452     # model code may need to be replayed in the presence of deterministic sites
#
# File ~/Documents/personal_workspace/hierarchical_prophet/.venv/lib/python3.11/site-packages/numpyro/handlers.py:171, in trace.get_trace(self, *args, **kwargs)
#     163 def get_trace(self, *args, **kwargs):
#     164     """
#     165     Run the wrapped callable and return the recorded trace.
#     166
#    (...)
#     169     :return: `OrderedDict` containing the execution trace.
#     170     """
# --> 171     self(*args, **kwargs)
#     172     return self.trace
#
# File ~/Documents/personal_workspace/hierarchical_prophet/.venv/lib/python3.11/site-packages/numpyro/primitives.py:105, in Messenger.__call__(self, *args, **kwargs)
#     103     return self
#     104 with self:
# --> 105     return self.fn(*args, **kwargs)
#
# File ~/Documents/personal_workspace/hierarchical_prophet/.venv/lib/python3.11/site-packages/numpyro/primitives.py:105, in Messenger.__call__(self, *args, **kwargs)
#     103     return self
#     104 with self:
# --> 105     return self.fn(*args, **kwargs)
#
# File ~/Documents/personal_workspace/hierarchical_prophet/.venv/lib/python3.11/site-packages/numpyro/primitives.py:105, in Messenger.__call__(self, *args, **kwargs)
#     103     return self
#     104 with self:
# --> 105     return self.fn(*args, **kwargs)
#
# File ~/Documents/personal_workspace/hierarchical_prophet/src/hierarchical_prophet/multivariate/model.py:67, in model(t, y, changepoint_matrix, init_trend_params, trend_mode, data, exogenous_effects, noise_scale, y_scale)
#      59         mean += effect
#      61 std_observation = numpyro.sample(
#      62     "std_observation", dist.HalfNormal(jnp.array([0.1] * mean.shape[0]))
#      63 )
#      65 correlation_matrix = numpyro.sample(
#      66     "corr_matrix",
# ---> 67     dist.LKJCholesky(
#      68         mean.shape[0],
#      69         concentration=1.0,
#      70     ),
#      71 )
#      73 noise_scale = std_observation * y_scale
#      75 cov_mat = jnp.diag(noise_scale) @ correlation_matrix @ jnp.diag(noise_scale)
#
# File ~/Documents/personal_workspace/hierarchical_prophet/.venv/lib/python3.11/site-packages/numpyro/distributions/distribution.py:99, in DistributionMeta.__call__(cls, *args, **kwargs)
#      97     if result is not None:
#      98         return result
# ---> 99 return super().__call__(*args, **kwargs)
#
# File ~/Documents/personal_workspace/hierarchical_prophet/.venv/lib/python3.11/site-packages/numpyro/distributions/continuous.py:999, in LKJCholesky.__init__(self, dimension, concentration, sample_method, validate_args)
#     995 def __init__(
#     996     self, dimension, concentration=1.0, sample_method="onion", *, validate_args=None
#     997 ):
#     998     if dimension < 2:
# --> 999         raise ValueError("Dimension must be greater than or equal to 2.")
#    1000     self.dimension = dimension
#    1001     self.concentration = concentration
#
# ValueError: Dimension must be greater than or equal to 2.

# %%
model_hier.plot_trace()
plt.show()

# %% [markdown]
# ## Forecasting with hierarchical prophet

# %%
preds_hier = model_hier.predict(fh=forecast_horizon)

fig, ax = plt.subplots(figsize=(10, 5))

preds_hier.droplevel(0).iloc[:, 0].rename("Hierarchical Prophet").plot.line(ax=ax)
preds.iloc[:, 0].rename("Prophet").plot.line(ax=ax)
# Plot y as scatter plot
ax.scatter(y.index, y, marker="o", color="k", s=2, alpha=0.5)
